# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.exceptions import ConvergenceWarning

# Ignore convergence warnings
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %%
df=pd.read_csv(r"C:\Users\Akshay\Downloads\archive (49)\sero_features_7.csv")

# %%
df.head()
# Out:
#    Target  AccMeanX  AccMeanY  AccMeanZ   AccCovX   AccCovY   AccCovZ  \
# 0       1  0.285339 -0.138611 -0.957764  0.022150  0.003975  0.001926
# 1       1  0.313477 -0.161670 -0.956250  0.020571  0.005640  0.001456
# 2       1  0.325195 -0.158325 -0.950155  0.017281  0.004579  0.001388
# 3       1  0.336565 -0.172468 -0.937640  0.015305  0.005216  0.002253
# 4       1  0.337860 -0.164185 -0.941681  0.013132  0.005020  0.002062
#
#    AccSkewX  AccSkewY  AccSkewZ  ...  GyroMaxZ  GyroVarX  GyroVarY  GyroVarZ  \
# 0  0.867594 -1.305868 -0.507254  ...  0.832061  0.761120  0.184372  0.262859
# 1  0.002474 -0.395088 -0.677572  ...  0.832061  3.061080  0.585991  0.270340
# 2 -0.354212 -0.603657 -0.984635  ...  0.832061  3.137076  0.552431  0.905518
# 3 -0.655653 -0.152454 -0.040530  ...  0.832061  2.809524  3.963056  0.893127
# 4 -0.718488 -0.446061  0.250539  ...  0.832061  2.667567  3.414394  0.799787
#
#    GyroMedianX  GyroMedianY  GyroMedianZ  GyroStdX  GyroStdY  GyroStdZ
# ...

# %%
df.sample(10)
# Out:
#       Target  AccMeanX  AccMeanY  AccMeanZ   AccCovX   AccCovY   AccCovZ  \
# 879        3  0.349923 -0.119524 -0.978690  0.009638  0.001536  0.001976
# 204        1  0.171387 -0.018328 -0.971872  0.021069  0.008954  0.014697
# 785        3  0.246704  0.097569 -1.013654  0.006532  0.092705  0.012699
# 199        1  0.210711 -0.046770 -0.990374  0.013013  0.003233  0.006214
# 190        1  0.282209 -0.110125 -0.923723  0.029089  0.008022  0.027816
# 1077       4  0.305821 -0.079538 -0.986869  0.081777  0.036954  0.001834
# 1044       4  0.382865 -0.167341 -0.993042  0.067423  0.030791  0.002568
# 992        4  0.324219 -0.111154 -0.989554  0.100361  0.040743  0.005153
# 367        2  0.204869 -0.164062 -0.993600  0.024885  0.028430  0.004207
# 77         1  0.329363 -0.136579 -1.037179  0.025415  0.005837  0.016829
#
#       AccSkewX  AccSkewY  AccSkewZ  ...   GyroMaxZ   GyroVarX   GyroVarY  \
# 879  -0.693395  0.120534  0.854967  ...   2.244275  12.608675   5.549163
# ...

# %%
df.shape
# Out:
# (1102, 61)

# %%
df.columns
# Out:
# Index(['Target', 'AccMeanX', 'AccMeanY', 'AccMeanZ', 'AccCovX', 'AccCovY',
#        'AccCovZ', 'AccSkewX', 'AccSkewY', 'AccSkewZ', 'AccKurtX', 'AccKurtY',
#        'AccKurtZ', 'AccSumX', 'AccSumY', 'AccSumZ', 'AccMinX', 'AccMinY',
#        'AccMinZ', 'AccMaxX', 'AccMaxY', 'AccMaxZ', 'AccVarX', 'AccVarY',
#        'AccVarZ', 'AccMedianX', 'AccMedianY', 'AccMedianZ', 'AccStdX',
#        'AccStdY', 'AccStdZ', 'GyroMeanX', 'GyroMeanY', 'GyroMeanZ', 'GyroCovX',
#        'GyroCovY', 'GyroCovZ', 'GyroSkewX', 'GyroSkewY', 'GyroSkewZ',
#        'GyroSumX', 'GyroSumY', 'GyroSumZ', 'GyroKurtX', 'GyroKurtY',
#        'GyroKurtZ', 'GyroMinX', 'GyroMinY', 'GyroMinZ', 'GyroMaxX', 'GyroMaxY',
#        'GyroMaxZ', 'GyroVarX', 'GyroVarY', 'GyroVarZ', 'GyroMedianX',
#        'GyroMedianY', 'GyroMedianZ', 'GyroStdX', 'GyroStdY', 'GyroStdZ'],
#       dtype='object')

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
## train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
# Calculate SVD
_, singular_values, _ = np.linalg.svd(x)

# Count non-zero singular values to find the rank
rank = np.count_nonzero(singular_values)
print("Rank of the matrix:", rank)
# Out:
# Rank of the matrix: 60

# %%
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=None)
x_train_trf=pca.fit_transform(x_train)
x_test_trf=pca.transform(x_test)

# %%
pca.explained_variance_.shape
# Out:
# (60,)

# %%
pca.components_.shape
# Out:
# (60, 60)

# %%
pca.explained_variance_ratio_
# Out:
# array([2.18146086e-01, 1.98766272e-01, 9.04552861e-02, 7.36828002e-02,
#        5.55726451e-02, 4.09861054e-02, 3.60030443e-02, 3.48709217e-02,
#        2.86097126e-02, 2.54004354e-02, 2.32371615e-02, 2.07909316e-02,
#        1.85671398e-02, 1.65193825e-02, 1.43019924e-02, 1.37219947e-02,
#        1.18953532e-02, 1.11321183e-02, 9.86869403e-03, 9.23820095e-03,
#        8.90735232e-03, 7.48427932e-03, 5.88386737e-03, 4.71662512e-03,
#        3.13021214e-03, 2.41774499e-03, 2.17265206e-03, 1.95931461e-03,
#        1.63317056e-03, 1.55597165e-03, 1.22950372e-03, 9.71109195e-04,
#        8.81938818e-04, 8.03139006e-04, 6.39049550e-04, 5.90168757e-04,
#        4.53238846e-04, 4.47331779e-04, 3.90691922e-04, 3.82110047e-04,
#        3.74708335e-04, 2.38448836e-04, 1.95378561e-04, 1.84394474e-04,
#        1.44064381e-04, 1.23843389e-04, 9.79119236e-05, 8.70407252e-05,
#        7.43401850e-05, 3.04631222e-05, 1.54427586e-05, 1.32334018e-05,
# ...

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.21814609, 0.41691236, 0.50736764, 0.58105044, 0.63662309,
#        0.67760919, 0.71361224, 0.74848316, 0.77709287, 0.80249331,
#        0.82573047, 0.8465214 , 0.86508854, 0.88160792, 0.89590992,
#        0.90963191, 0.92152726, 0.93265938, 0.94252808, 0.95176628,
#        0.96067363, 0.96815791, 0.97404178, 0.9787584 , 0.98188861,
#        0.98430636, 0.98647901, 0.98843833, 0.9900715 , 0.99162747,
#        0.99285697, 0.99382808, 0.99471002, 0.99551316, 0.99615221,
#        0.99674238, 0.99719562, 0.99764295, 0.99803364, 0.99841575,
#        0.99879046, 0.99902891, 0.99922428, 0.99940868, 0.99955274,
#        0.99967659, 0.9997745 , 0.99986154, 0.99993588, 0.99996634,
#        0.99998179, 0.99999502, 0.99999915, 1.        , 1.        ,
#        1.        , 1.        , 1.        , 1.        , 1.        ])

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))

# %%
pca=PCA(n_components=24)
x_train_trf=pca.fit_transform(x_train)
x_test_trf=pca.transform(x_test)

# %%
### Hyperparameter Tuning
### Gredsearch
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier=LogisticRegression()

# %%
parameters={"penalty":("l1","l2","elasticnet",None),"C":[1,10,20]}

# %%
clf=GridSearchCV(classifier,param_grid=parameters,cv=5)

# %%
## Split of train data to validation data
clf.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [1, 10, 20],
#                          'penalty': ('l1', 'l2', 'elasticnet', None)})

# %%
clf.best_params_
# Out:
# {'C': 20, 'penalty': 'l2'}

# %%
classifier=LogisticRegression(C=20,penalty="l2")

# %%
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression(C=20)

# %%
## For the prediction
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print("confusion_matrix",confusion_matrix(y_pred,y_test))
print("accuracy_score",accuracy_score(y_pred,y_test))
print("classification_report",classification_report(y_pred,y_test))
# Out:
# confusion_matrix [[53  1  1  0]
#  [ 0 59  0  0]
#  [ 0  0 68  0]
#  [ 0  0  0 39]]
# accuracy_score 0.9909502262443439
# classification_report               precision    recall  f1-score   support
#
#            1       1.00      0.96      0.98        55
#            2       0.98      1.00      0.99        59
#            3       0.99      1.00      0.99        68
#            4       1.00      1.00      1.00        39
#
#     accuracy                           0.99       221
#    macro avg       0.99      0.99      0.99       221
# weighted avg       0.99      0.99      0.99       221

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_classifier=KNeighborsClassifier()

# %%
# Define grid search parameters
param_grid = {
    'n_neighbors': [3, 5, 7],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'p': [1, 2]
}

# %%
# Perform grid search
grid_search_knn = GridSearchCV(knn_classifier, param_grid, cv=5, verbose=1, n_jobs=-1)
grid_search_knn.fit(x, y)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [3, 5, 7], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              verbose=1)

# %%
grid_search_knn.best_params_
# Out:
# {'algorithm': 'auto', 'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7, weights='uniform', algorithm='auto')

# %%
## Split of train data to validation data
grid_search_knn.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [3, 5, 7], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              verbose=1)

# %%
y_pred_knn=grid_search_knn.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print("confusion_matrix",confusion_matrix(y_pred_knn,y_test))
print("accuracy_score",accuracy_score(y_pred_knn,y_test))
print("classification_report",classification_report(y_pred_knn,y_test))
# Out:
# confusion_matrix [[53  0  0  0]
#  [ 0 59  0  0]
#  [ 0  1 69  0]
#  [ 0  0  0 39]]
# accuracy_score 0.995475113122172
# classification_report               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        53
#            2       0.98      1.00      0.99        59
#            3       1.00      0.99      0.99        70
#            4       1.00      1.00      1.00        39
#
#     accuracy                           1.00       221
#    macro avg       1.00      1.00      1.00       221
# weighted avg       1.00      1.00      1.00       221

# %%
import pickle 
pickle.dump(grid_search_knn,open("grid_search_knn.pickle","wb"))

# %%
grid_search_knn=pickle.load(open("grid_search_knn.pickle","rb"))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Define DecisionTreeClassifier
tree = DecisionTreeClassifier()

# %%
# Define grid search parameters
param_grid = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
# Perform grid search
grid_search_dt = GridSearchCV(tree, param_grid, cv=5, verbose=1, n_jobs=-1)
grid_search_dt.fit(x, y)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
grid_search_dt.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': None,
#  'min_samples_leaf': 4,
#  'min_samples_split': 10,
#  'splitter': 'random'}

# %%
tree=DecisionTreeClassifier(criterion='entropy',max_depth=20,min_samples_leaf=1,min_samples_split=5,splitter='random')

# %%
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=20, min_samples_split=5,
#                        splitter='random')

# %%
y_pred_tree=tree.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print("confusion_matrix",confusion_matrix(y_pred_tree,y_test))
print("accuracy_score",accuracy_score(y_pred_tree,y_test))
print("classification_report",classification_report(y_pred_tree,y_test))
# Out:
# confusion_matrix [[53  0  3  0]
#  [ 0 60  0  0]
#  [ 0  0 66  0]
#  [ 0  0  0 39]]
# accuracy_score 0.9864253393665159
# classification_report               precision    recall  f1-score   support
#
#            1       1.00      0.95      0.97        56
#            2       1.00      1.00      1.00        60
#            3       0.96      1.00      0.98        66
#            4       1.00      1.00      1.00        39
#
#     accuracy                           0.99       221
#    macro avg       0.99      0.99      0.99       221
# weighted avg       0.99      0.99      0.99       221

# %%
from sklearn.ensemble import RandomForestClassifier
# Define RandomForestClassifier
forest = RandomForestClassifier()

# %%
# Define grid search parameters
param_grid = {
    'n_estimators': [50, 100, 200],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
# Perform grid search
grid_search = GridSearchCV(forest, param_grid, cv=5, verbose=1, n_jobs=-1)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              verbose=1)

# %%
# Print best parameters and best score
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}

# %%
grid_search_forest=RandomForestClassifier()

# %%
grid_search_forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_forest=grid_search_forest.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print("confusion_matrix",confusion_matrix(y_pred_forest,y_test))
print("accuracy_score",accuracy_score(y_pred_forest,y_test))
print("classification_report",classification_report(y_pred_forest,y_test))
# Out:
# confusion_matrix [[53  0  0  0]
#  [ 0 60  0  0]
#  [ 0  0 69  0]
#  [ 0  0  0 39]]
# accuracy_score 1.0
# classification_report               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        53
#            2       1.00      1.00      1.00        60
#            3       1.00      1.00      1.00        69
#            4       1.00      1.00      1.00        39
#
#     accuracy                           1.00       221
#    macro avg       1.00      1.00      1.00       221
# weighted avg       1.00      1.00      1.00       221

# %%
from sklearn.ensemble import AdaBoostClassifier
# Define AdaBoostClassifier
adaboost = AdaBoostClassifier()

# Define grid search parameters
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1.0],
    'algorithm': ['SAMME', 'SAMME.R']
}

# Perform grid search
grid_search = GridSearchCV(adaboost, param_grid, cv=5, verbose=1, n_jobs=-1)
grid_search.fit(x_train, y_train)

# Print best parameters and best score
print("Best Parameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best Parameters: {'algorithm': 'SAMME', 'learning_rate': 1.0, 'n_estimators': 100}

# %%
adaboost= AdaBoostClassifier(algorithm='SAMME',learning_rate=1.0,n_estimators=100)

# %%
adaboost.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME', n_estimators=100)

# %%
y_pred_adaboost=adaboost.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print("confusion_matrix",confusion_matrix(y_pred_adaboost,y_test))
print("accuracy_score",accuracy_score(y_pred_adaboost,y_test))
print("classification_report",classification_report(y_pred_adaboost,y_test))
# Out:
# confusion_matrix [[51  0  3  1]
#  [ 0 60  0  0]
#  [ 2  0 66  0]
#  [ 0  0  0 38]]
# accuracy_score 0.9728506787330317
# classification_report               precision    recall  f1-score   support
#
#            1       0.96      0.93      0.94        55
#            2       1.00      1.00      1.00        60
#            3       0.96      0.97      0.96        68
#            4       0.97      1.00      0.99        38
#
#     accuracy                           0.97       221
#    macro avg       0.97      0.97      0.97       221
# weighted avg       0.97      0.97      0.97       221
