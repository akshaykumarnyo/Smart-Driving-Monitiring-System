# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Akshay\Downloads\archive (49)\sero_features_7.csv")

# %%
df.head()
# Out:
#    Target  AccMeanX  AccMeanY  AccMeanZ   AccCovX   AccCovY   AccCovZ  \
# 0       1  0.285339 -0.138611 -0.957764  0.022150  0.003975  0.001926
# 1       1  0.313477 -0.161670 -0.956250  0.020571  0.005640  0.001456
# 2       1  0.325195 -0.158325 -0.950155  0.017281  0.004579  0.001388
# 3       1  0.336565 -0.172468 -0.937640  0.015305  0.005216  0.002253
# 4       1  0.337860 -0.164185 -0.941681  0.013132  0.005020  0.002062
#
#    AccSkewX  AccSkewY  AccSkewZ  ...  GyroMaxZ  GyroVarX  GyroVarY  GyroVarZ  \
# 0  0.867594 -1.305868 -0.507254  ...  0.832061  0.761120  0.184372  0.262859
# 1  0.002474 -0.395088 -0.677572  ...  0.832061  3.061080  0.585991  0.270340
# 2 -0.354212 -0.603657 -0.984635  ...  0.832061  3.137076  0.552431  0.905518
# 3 -0.655653 -0.152454 -0.040530  ...  0.832061  2.809524  3.963056  0.893127
# 4 -0.718488 -0.446061  0.250539  ...  0.832061  2.667567  3.414394  0.799787
#
#    GyroMedianX  GyroMedianY  GyroMedianZ  GyroStdX  GyroStdY  GyroStdZ
# 0    -0.286260     4.251908     0.706107  0.872422  0.429385  0.512697
# 1     0.335878     3.969466     0.587786  1.749594  0.765501  0.519942
# 2    -0.286260     3.832061     0.240458  1.771179  0.743257  0.951587
# 3     0.335878     3.969466    -0.106870  1.676163  1.990743  0.945054
# 4    -0.286260     4.038168    -0.179389  1.633269  1.847808  0.894308
#
# [5 rows x 61 columns]

# %%
df.sample(10)
# Out:
#       Target  AccMeanX  AccMeanY  AccMeanZ   AccCovX   AccCovY   AccCovZ  \
# 789        3  0.260306  0.109863 -0.975970  0.007955  0.083717  0.016039
# 563        3  0.285836 -0.011632 -0.987444  0.007867  0.051447  0.009827
# 131        1  0.297782 -0.102382 -1.012085  0.036142  0.016690  0.019261
# 513        2  0.220738 -0.167620 -0.999581  0.014002  0.020705  0.007465
# 660        3  0.259382  0.042672 -0.984392  0.011883  0.060252  0.008862
# 916        4  0.045532  0.034947 -0.989711  0.008269  0.003257  0.001356
# 1058       4  0.287510 -0.076503 -0.960903  0.052431  0.026821  0.007707
# 1015       4  0.390677 -0.144444 -0.994524  0.091358  0.040899  0.004479
# 657        3  0.257028  0.046369 -0.988909  0.011557  0.058668  0.005646
# 21         1  0.390747 -0.162371 -0.960188  0.024614  0.004873  0.007600
#
#       AccSkewX  AccSkewY  AccSkewZ  ...   GyroMaxZ   GyroVarX   GyroVarY  \
# 789  -0.299446  0.944603 -0.718681  ...  43.343511  19.567432  30.618769
# 563   0.080734  1.220306  0.080316  ...  41.015267  11.052309  14.266415
# 131   0.008810  0.708889 -1.491467  ...   7.549618   9.292446  15.953252
# 513  -0.719001 -1.628459 -0.702998  ...   2.343511  12.462289   8.491169
# 660  -1.485266  0.598856  0.136518  ...  41.007634   3.216142   8.482846
# 916   1.653773 -0.754401 -0.286121  ...   1.625954   1.755290   3.521755
# 1058  0.036538 -0.103940 -0.878917  ...   2.083969   4.749849   1.547060
# 1015 -0.183477  0.279610  1.299793  ...   1.770992   8.295941   1.592193
# 657  -1.496823  0.608045 -0.342284  ...  41.007634   3.323106   8.389314
# 21   -0.186616 -0.223284  0.549684  ...   1.946565   3.783927   6.436355
#
#         GyroVarZ  GyroMedianX  GyroMedianY  GyroMedianZ  GyroStdX  GyroStdY  \
# 789   282.241363    -1.450382     2.919847     2.286260  4.423509  5.533423
# 563   225.119098    -1.198473     4.381679     1.019084  3.324501  3.777091
# 131     5.362028    -0.259542     4.641221     0.843511  3.048351  3.994152
# 513   159.944596    -2.152672     4.381679     0.354962  3.530197  2.913961
# 660   202.243624    -2.221374     4.110687     2.183206  1.793361  2.912533
# 916     0.167569    -0.187023     5.076336     0.908397  1.324874  1.876634
# 1058    0.479400    -0.721374     4.992366     1.072519  2.179415  1.243809
# 1015    0.119544    -0.389313     4.812977     0.923664  2.880268  1.261821
# 657   196.602608    -1.660305     3.854962     1.530534  1.822939  2.896431
# 21      0.790080    -0.599237     4.412214     0.812977  1.945232  2.536997
#
#        GyroStdZ
# 789   16.800041
# 563   15.003969
# 131    2.315605
# 513   12.646920
# 660   14.221238
# 916    0.409352
# 1058   0.692387
# 1015   0.345751
# 657   14.021505
# 21     0.888865
#
# [10 rows x 61 columns]

# %%
df.shape
# Out:
# (1102, 61)

# %%
df.columns
# Out:
# Index(['Target', 'AccMeanX', 'AccMeanY', 'AccMeanZ', 'AccCovX', 'AccCovY',
#        'AccCovZ', 'AccSkewX', 'AccSkewY', 'AccSkewZ', 'AccKurtX', 'AccKurtY',
#        'AccKurtZ', 'AccSumX', 'AccSumY', 'AccSumZ', 'AccMinX', 'AccMinY',
#        'AccMinZ', 'AccMaxX', 'AccMaxY', 'AccMaxZ', 'AccVarX', 'AccVarY',
#        'AccVarZ', 'AccMedianX', 'AccMedianY', 'AccMedianZ', 'AccStdX',
#        'AccStdY', 'AccStdZ', 'GyroMeanX', 'GyroMeanY', 'GyroMeanZ', 'GyroCovX',
#        'GyroCovY', 'GyroCovZ', 'GyroSkewX', 'GyroSkewY', 'GyroSkewZ',
#        'GyroSumX', 'GyroSumY', 'GyroSumZ', 'GyroKurtX', 'GyroKurtY',
#        'GyroKurtZ', 'GyroMinX', 'GyroMinY', 'GyroMinZ', 'GyroMaxX', 'GyroMaxY',
#        'GyroMaxZ', 'GyroVarX', 'GyroVarY', 'GyroVarZ', 'GyroMedianX',
#        'GyroMedianY', 'GyroMedianZ', 'GyroStdX', 'GyroStdY', 'GyroStdZ'],
#       dtype='object')

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
## train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
### Hyperparameter Tuning
### Gredsearch
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier=LogisticRegression()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
parameters={"penalty":("l1","l2","elasticnet",None),"C":[1,10,20]}

# %%
clf=GridSearchCV(classifier,param_grid=parameters,cv=5)

# %%
clf.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [1, 10, 20],
#                          'penalty': ('l1', 'l2', 'elasticnet', None)})

# %%
clf.best_params_
# Out:
# {'C': 1, 'penalty': 'l2'}

# %%
classifier=LogisticRegression(C=1,penalty="l2")

# %%
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1)

# %%
## For the prediction
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(confusion_matrix(y_pred,y_test))
print(accuracy_score(y_pred,y_test))
print(classification_report(y_pred,y_test))
# Out:
# [[50  1  2  0]
#  [ 0 59  0  0]
#  [ 1  0 65  0]
#  [ 2  0  2 39]]
# 0.9638009049773756
#               precision    recall  f1-score   support
#
#            1       0.94      0.94      0.94        53
#            2       0.98      1.00      0.99        59
#            3       0.94      0.98      0.96        66
#            4       1.00      0.91      0.95        43
#
#     accuracy                           0.96       221
#    macro avg       0.97      0.96      0.96       221
# weighted avg       0.96      0.96      0.96       221

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
# Calculate SVD
_, singular_values, _ = np.linalg.svd(x)

# Count non-zero singular values to find the rank
rank = np.count_nonzero(singular_values)
print("Rank of the matrix:", rank)
# Out:
# Rank of the matrix: 60

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=None)
x_train_trf=pca.fit_transform(x_train)
x_test_trf=pca.transform(x_test)

# %%
pca.explained_variance_.shape
# Out:
# (60,)

# %%
pca.components_.shape
# Out:
# (60, 60)

# %%
pca.explained_variance_ratio_
# Out:
# array([2.17138920e-01, 1.99368819e-01, 9.03383317e-02, 7.51472805e-02,
#        5.59784643e-02, 4.11101088e-02, 3.58053629e-02, 3.49323350e-02,
#        2.84411056e-02, 2.52518177e-02, 2.32517620e-02, 2.07425358e-02,
#        1.83521088e-02, 1.64667201e-02, 1.41532773e-02, 1.36781132e-02,
#        1.17476775e-02, 1.11110625e-02, 9.78105919e-03, 9.19007895e-03,
#        8.88254784e-03, 7.50619174e-03, 5.79300081e-03, 4.70286492e-03,
#        3.13423157e-03, 2.41869032e-03, 2.15113446e-03, 1.93441761e-03,
#        1.61894102e-03, 1.53437790e-03, 1.22313858e-03, 9.79355722e-04,
#        8.80259699e-04, 7.92515882e-04, 6.31789317e-04, 5.91277622e-04,
#        4.53246444e-04, 4.41031532e-04, 3.92136637e-04, 3.76296279e-04,
#        3.71698631e-04, 2.38511679e-04, 1.93654575e-04, 1.82447227e-04,
#        1.42984813e-04, 1.23331963e-04, 9.75852811e-05, 8.80065515e-05,
#        7.36183903e-05, 3.08887720e-05, 1.50840451e-05, 1.29361776e-05,
#        4.03531860e-06, 8.30247609e-07, 3.00421577e-30, 4.43792152e-32,
#        3.01749798e-32, 2.19931048e-32, 1.10173132e-32, 5.98475139e-33])

# %%
np.cumsum(pca.explained_variance_ratio_)
# Out:
# array([0.21713892, 0.41650774, 0.50684607, 0.58199335, 0.63797182,
#        0.67908192, 0.71488729, 0.74981962, 0.77826073, 0.80351255,
#        0.82676431, 0.84750684, 0.86585895, 0.88232567, 0.89647895,
#        0.91015706, 0.92190474, 0.9330158 , 0.94279686, 0.95198694,
#        0.96086949, 0.96837568, 0.97416868, 0.97887155, 0.98200578,
#        0.98442447, 0.9865756 , 0.98851002, 0.99012896, 0.99166334,
#        0.99288648, 0.99386583, 0.99474609, 0.99553861, 0.9961704 ,
#        0.99676168, 0.99721492, 0.99765595, 0.99804809, 0.99842439,
#        0.99879608, 0.9990346 , 0.99922825, 0.9994107 , 0.99955368,
#        0.99967702, 0.9997746 , 0.99986261, 0.99993623, 0.99996711,
#        0.9999822 , 0.99999513, 0.99999917, 1.        , 1.        ,
#        1.        , 1.        , 1.        , 1.        , 1.        ])

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))

# %%
pca=PCA(n_components=24)
x_train_trf=pca.fit_transform(x_train)
x_test_trf=pca.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train_trf,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lr=lr.predict(x_test_trf)

# %%
from sklearn.metrics import accuracy_score
print("Actual",accuracy_score(y_test,y_pred_lr))
# Out:
# Actual 0.9849246231155779

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train_trf,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt=dt.predict(x_test_trf)

# %%
print("Actual",accuracy_score(y_test,y_pred_dt))
# Out:
# Actual 0.9748743718592965

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train_trf,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn=knn.predict(x_test_trf)

# %%
print("Actual",accuracy_score(y_test,y_pred_knn))
# Out:
# Actual 0.9899497487437185

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.96      1.00      0.98        47
#            2       1.00      0.98      0.99        54
#            3       1.00      0.98      0.99        64
#            4       1.00      1.00      1.00        34
#
#     accuracy                           0.99       199
#    macro avg       0.99      0.99      0.99       199
# weighted avg       0.99      0.99      0.99       199

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.96      0.98      0.97        47
#            2       0.96      1.00      0.98        54
#            3       0.98      0.94      0.96        64
#            4       1.00      1.00      1.00        34
#
#     accuracy                           0.97       199
#    macro avg       0.98      0.98      0.98       199
# weighted avg       0.98      0.97      0.97       199

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(classification_report(y_test,y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.94      1.00      0.97        47
#            2       1.00      0.98      0.99        54
#            3       1.00      0.97      0.98        64
#            4       1.00      1.00      1.00        34
#
#     accuracy                           0.98       199
#    macro avg       0.98      0.99      0.99       199
# weighted avg       0.99      0.98      0.99       199

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

conf_matrix = confusion_matrix(y_test, y_pred_knn)

# Plot the confusion matrix using ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=dt.classes_)
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

conf_matrix = confusion_matrix(y_test, y_pred_dt)

# Plot the confusion matrix using ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=dt.classes_)
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

conf_matrix = confusion_matrix(y_test, y_pred_lr)

# Plot the confusion matrix using ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=dt.classes_)
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix')
plt.show()
